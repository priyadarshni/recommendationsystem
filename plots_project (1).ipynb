# %%
import pandas as pd
import numpy as np
import io
import requests
url="https://raw.githubusercontent.com/travisdesell/exact/master/datasets/2018_coal/burner_0.csv"
s=requests.get(url).content
df=pd.read_csv(io.StringIO(s.decode('utf-8')))
df
# Out:
#        Conditioner_Inlet_Temp  Conditioner_Outlet_Temp  Coal_Feeder_Rate  \
# 0                    0.599950                 0.371572          0.920551
# 1                    0.602043                 0.370189          0.913209
# 2                    0.598725                 0.365300          0.923316
# 3                    0.598352                 0.372956          0.907022
# 4                    0.600201                 0.371572          0.920551
# 5                    0.598108                 0.373892          0.917366
# 6                    0.598352                 0.370650          0.923640
# 7                    0.593176                 0.369253          0.920140
# 8                    0.592073                 0.371111          0.921199
# 9                    0.592316                 0.376197          0.917042
# 10                   0.596137                 0.374353          0.927797
# 11                   0.598847                 0.374353          0.943119
# ...

# %%
from pandas import DataFrame

import seaborn as sn
from matplotlib.pyplot import figure
figure(num=None, figsize=(10, 6), dpi=80, facecolor='w', edgecolor='k')
corrMatrix = df.corr()
sn.heatmap(corrMatrix, annot=True)

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(20, 10), dpi=80, facecolor='w', edgecolor='k')
ax = df.plot.hist(bins=12, alpha=0.5)
ax

# %%
import matplotlib.pyplot as plt
import pandas as pd

# a scatter plot comparing num_children and num_pets
df.plot(kind='scatter',x='Primary_Air_Flow',y='Main_Flm_Int',color='black')
plt.show()

# %%
df.plot(kind='scatter',x='Primary_Air_Split',y='Main_Flm_Int',color='black')
plt.show()

# %%
df.plot(kind='scatter',x='Total_Comb_Air_Flow',y='Main_Flm_Int',color='black')
plt.show()

# %%
df.plot(kind='scatter',x='Secondary_Air_Split',y='Main_Flm_Int',color='black')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# gca stands for 'get current axis'
ax = plt.gca()

df.plot(kind='line',x='Primary_Air_Flow',y='Main_Flm_Int',ax=ax)
df.plot(kind='line',x='Primary_Air_Split',y='Main_Flm_Int', color='red', ax=ax)

plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# gca stands for 'get current axis'
ax = plt.gca()

df.plot(kind='line',x='Primary_Air_Flow',y='Main_Flm_Int',ax=ax)
df.plot(kind='line',x='Primary_Air_Split',y='Main_Flm_Int', color='red', ax=ax)
df.plot(kind='line',x='Total_Comb_Air_Flow',y='Main_Flm_Int', color='green', ax=ax)
df.plot(kind='line',x='Secondary_Air_Split',y='Main_Flm_Int', color='blue', ax=ax)
plt.show()

# %%
df.hist(column='Primary_Air_Flow')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001CAB02FDEB8>]],
#       dtype=object)

# %%
df.hist(column='Primary_Air_Split')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001CAAF966C88>]],
#       dtype=object)

# %%
df.hist(bins = 5)
plt.show()

# %%
import seaborn
seaborn.distplot(df['Primary_Air_Flow'])

# %%
seaborn.distplot(df['Primary_Air_Split'])

# %%
seaborn.distplot(df['Total_Comb_Air_Flow'])

# %%
seaborn.distplot(df['Secondary_Air_Split'])
